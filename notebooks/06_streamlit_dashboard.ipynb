# %% [markdown]
# # 06 - Launch live Streamlit dashboard
#
# Streamlit runs as a web service, not inside normal notebook output. Run it in an AIDP application/terminal that exposes web ports.

# %%
# Install once in the Streamlit runtime if needed.
# %pip install streamlit

# Start the app; AIDP must route this port to your browser.
# !streamlit run /Workspace/ORACLE_AIDP_STREAMING/streamlit_app.py --server.address 0.0.0.0 --server.port 8501
